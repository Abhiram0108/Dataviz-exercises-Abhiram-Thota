# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhiram0108/Dataviz-exercises-Abhiram-Thota/blob/main/week02/lecture02_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## TASK 1


import numpy as np
region_avg = (
    df.groupby('Region')['Happiness_Score']
    .mean()
    .sort_values(ascending=True)
    .reset_index()
)

# Step 2: Create horizontal bar chart
fig1 = px.bar(
    region_avg,
    x='Happiness_Score',
    y='Region',
    orientation='h',
    title='Average Happiness Score by Region (2023)',
    color='Happiness_Score',
    color_continuous_scale='viridis'
)

# Step 3: Improve layout
fig1.update_layout(
    xaxis_title='Average Happiness Score',
    yaxis_title='Region',
    template='plotly_white'
)

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## TASK 1


import numpy as np
combined['Country'] = combined['Region']

# Task 2: Top 8 vs. Bottom 8 contrast
# ------------------------------------

# Step 1: Get top and bottom countries
top8 = df.nlargest(8, 'Happiness_Score').copy()
top8['Group'] = 'Top 8'

bottom8 = df.nsmallest(8, 'Happiness_Score').copy()
bottom8['Group'] = 'Bottom 8'

# Combine
combined = pd.concat([top8, bottom8])

# Step 2: Create bar chart
fig2 = px.bar(
    combined,
    x='Region',
    y='Happiness_Score',
    color='Group',
    title='Top 8 vs Bottom 8 Happiest Countries (2023)',
    barmode='group'
)

# Step 3: Improve layout
fig2.update_layout(
    xaxis_title='Region',
    yaxis_title='Happiness Score',
    template='plotly_white'
)

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
